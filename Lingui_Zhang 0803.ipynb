# %%
import pandas as pd
import  numpy as np
import datetime
import matplotlib as mpl
import matplotlib.pyplot as plt

from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
df_2015 = pd.read_csv("C:/Users/kzking/Desktop/archive/2015.csv")
df_2016 = pd.read_csv("C:/Users/kzking/Desktop/archive/2016.csv")
df_2017 = pd.read_csv("C:/Users/kzking/Desktop/archive/2017.csv")
df_2018 = pd.read_csv("C:/Users/kzking/Desktop/archive/2018.csv")
df_2019 = pd.read_csv("C:/Users/kzking/Desktop/archive/2019.csv")
df_2020 = pd.read_csv("C:/Users/kzking/Desktop/archive/2020.csv")
df_2021 = pd.read_csv("C:/Users/kzking/Desktop/archive/2021.csv")
df_2022 = pd.read_csv("C:/Users/kzking/Desktop/archive/2022.csv")

# %%
df_2021.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe         7.842
# 1      Denmark         Western Europe         7.620
# 2  Switzerland         Western Europe         7.571
# 3      Iceland         Western Europe         7.554
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
# ...

# %%
df_2015['Year'] = 2015
df_2016['Year'] = 2016
df_2017['Year'] = 2017
df_2018['Year'] = 2018
df_2019['Year'] = 2019
df_2020['Year'] = 2020
df_2021['Year'] = 2021
df_2022['Year'] = 2022

# %%
df_2016.tail(10)
# Out:
#          Country                           Region  Happiness Rank  \
# 147   Madagascar               Sub-Saharan Africa             148
# 148     Tanzania               Sub-Saharan Africa             149
# 149      Liberia               Sub-Saharan Africa             150
# 150       Guinea               Sub-Saharan Africa             151
# 151       Rwanda               Sub-Saharan Africa             152
# 152        Benin               Sub-Saharan Africa             153
# 153  Afghanistan                    Southern Asia             154
# 154         Togo               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
#
#      Happiness Score  Lower Confidence Interval  Upper Confidence Interval  \
# 147            3.695                      3.621                      3.769
# 148            3.666                      3.561                      3.771
# ...

# %%
diff_2015 = df_2015.loc[(df_2015['Country'] == 'Switzerland') ^ (df_2015['Country']== 'Afghanistan')]
diff_2015.head()
diff_2016 = df_2016.loc[(df_2016['Country'] == 'Switzerland') ^ (df_2016['Country']== 'Afghanistan')]
diff_2016.head()
diff_2017 = df_2017.loc[(df_2017['Country'] == 'Switzerland') ^ (df_2017['Country']== 'Afghanistan')]
diff_2017.head()
diff_2018 = df_2018.loc[(df_2018['Country or region'] == 'Switzerland') ^ (df_2018['Country or region']== 'Afghanistan')]
diff_2018.head()
diff_2019 = df_2019.loc[(df_2019['Country or region'] == 'Switzerland') ^ (df_2019['Country or region']== 'Afghanistan')]
diff_2019.head()
diff_2020 = df_2020.loc[(df_2020['Country name'] == 'Switzerland') ^ (df_2020['Country name']== 'Afghanistan')]
diff_2020.head()
diff_2021 = df_2021.loc[(df_2021['Country name'] == 'Switzerland') ^ (df_2021['Country name']== 'Afghanistan')]
diff_2021.head()
diff_2022 = df_2022.loc[(df_2022['Country'] == 'Switzerland') ^ (df_2022['Country']== 'Afghanistan')]
diff_2022.head()
# Out:
#      RANK      Country Happiness score Whisker-high Whisker-low  \
# 3       4  Switzerland           7,512        7,586       7,437
# 145   146  Afghanistan           2,404        2,469       2,339
#
#     Dystopia (1.83) + residual Explained by: GDP per capita  \
# 3                        2,153                        2,026
# 145                      1,263                        0,758
#
#     Explained by: Social support Explained by: Healthy life expectancy  \
# 3                          1,226                                 0,822
# 145                        0,000                                 0,289
#
#     Explained by: Freedom to make life choices Explained by: Generosity  \
# 3                                        0,677                    0,147
# 145                                      0,000                    0,089
#
#     Explained by: Perceptions of corruption  Year
# 3                                     0,461  2022
# ...

# %%
diff_2015 = diff_2015[['Year','Country','Happiness Score','Health (Life Expectancy)','Trust (Government Corruption)','Generosity','Economy (GDP per Capita)','Freedom']]
diff_2015.rename(columns={'Happiness Score':'Happiness'},inplace=True)
diff_2015.rename(columns={'Health (Life Expectancy)':'Health'},inplace=True)
diff_2015.rename(columns={'Trust (Government Corruption)':'Trust'},inplace=True)
diff_2015.rename(columns={'Economy (GDP per Capita)':'Economy'},inplace=True)

diff_2015
# Out:
#      Year      Country  Happiness   Health    Trust  Generosity  Economy  \
# 0    2015  Switzerland      7.587  0.94143  0.41978     0.29678  1.39651
# 152  2015  Afghanistan      3.575  0.30335  0.09719     0.36510  0.31982
#
#      Freedom
# 0    0.66557
# 152  0.23414

# %%
diff_2016 = diff_2016[['Year','Country','Happiness Score','Health (Life Expectancy)','Trust (Government Corruption)','Generosity','Economy (GDP per Capita)','Freedom']]
diff_2016.rename(columns={'Happiness Score':'Happiness'},inplace=True)
diff_2016.rename(columns={'Health (Life Expectancy)':'Health'},inplace=True)
diff_2016.rename(columns={'Trust (Government Corruption)':'Trust'},inplace=True)
diff_2016.rename(columns={'Economy (GDP per Capita)':'Economy'},inplace=True)
diff_2016
# Out:
#      Year      Country  Happiness   Health    Trust  Generosity  Economy  \
# 1    2016  Switzerland      7.509  0.86303  0.41203     0.28083  1.52733
# 153  2016  Afghanistan      3.360  0.17344  0.07112     0.31268  0.38227
#
#      Freedom
# 1    0.58557
# 153  0.16430

# %%
diff_2017 = diff_2017[['Year','Country','Happiness.Score','Health..Life.Expectancy.','Trust..Government.Corruption.','Generosity','Economy..GDP.per.Capita.','Freedom']]
diff_2017.rename(columns={'Happiness.Score':'Happiness'},inplace=True)
diff_2017.rename(columns={'Health..Life.Expectancy.':'Health'},inplace=True)
diff_2017.rename(columns={'Trust..Government.Corruption.':'Trust'},inplace=True)
diff_2017.rename(columns={'Economy..GDP.per.Capita.':'Economy'},inplace=True)
diff_2017
# Out:
#      Year      Country  Happiness    Health     Trust  Generosity   Economy  \
# 3    2017  Switzerland      7.494  0.858131  0.367007    0.290549  1.564980
# 140  2017  Afghanistan      3.794  0.180747  0.061158    0.311871  0.401477
#
#       Freedom
# 3    0.620071
# 140  0.106180

# %%
diff_2018 = diff_2018[['Year','Country or region','Score','Healthy life expectancy','Perceptions of corruption','Generosity','GDP per capita','Freedom to make life choices']]
diff_2018.rename(columns={'Country or region':'Country'},inplace=True)
diff_2018.rename(columns={'Score':'Happiness'},inplace=True)
diff_2018.rename(columns={'Healthy life expectancy':'Health'},inplace=True)
diff_2018.rename(columns={'Perceptions of corruption':'Trust'},inplace=True)
diff_2018.rename(columns={'GDP per capita':'Economy'},inplace=True)
diff_2018.rename(columns={'Freedom to make life choices':'Freedom'},inplace=True)
diff_2018
# Out:
#      Year      Country  Happiness  Health  Trust  Generosity  Economy  Freedom
# 4    2018  Switzerland      7.487   0.927  0.357       0.256    1.420    0.660
# 144  2018  Afghanistan      3.632   0.255  0.036       0.191    0.332    0.085

# %%
diff_2019 = diff_2019[['Year','Country or region','Score','Healthy life expectancy','Perceptions of corruption','Generosity','GDP per capita','Freedom to make life choices']]
diff_2019.rename(columns={'Country or region':'Country'},inplace=True)
diff_2019.rename(columns={'Score':'Happiness'},inplace=True)
diff_2019.rename(columns={'Healthy life expectancy':'Health'},inplace=True)
diff_2019.rename(columns={'Perceptions of corruption':'Trust'},inplace=True)
diff_2019.rename(columns={'GDP per capita':'Economy'},inplace=True)
diff_2019.rename(columns={'Freedom to make life choices':'Freedom'},inplace=True)
diff_2019
# Out:
#      Year      Country  Happiness  Health  Trust  Generosity  Economy  Freedom
# 5    2019  Switzerland      7.480   1.052  0.343       0.263    1.452    0.572
# 153  2019  Afghanistan      3.203   0.361  0.025       0.158    0.350    0.000

# %%
diff_2020 = diff_2020[['Year','Country name','Ladder score','Healthy life expectancy','Explained by: Perceptions of corruption','Generosity','Logged GDP per capita','Explained by: Freedom to make life choices']]
diff_2020.rename(columns={'Ladder score':'Happiness'},inplace=True)
diff_2020.rename(columns={'Healthy life expectancy':'Health'},inplace=True)
diff_2020.rename(columns={'Explained by: Perceptions of corruption':'Trust'},inplace=True)
diff_2020.rename(columns={'Logged GDP per capita':'Economy'},inplace=True)
diff_2020.rename(columns={'Explained by: Freedom to make life choices':'Freedom'},inplace=True)
diff_2020.rename(columns={'Country name':'Country'},inplace=True)
diff_2020
# Out:
#      Year      Country  Happiness     Health     Trust  Generosity    Economy  \
# 2    2020  Switzerland     7.5599  74.102448  0.407946    0.105911  10.979933
# 152  2020  Afghanistan     2.5669  52.590000  0.001226   -0.096429   7.462861
#
#       Freedom
# 2    0.628954
# 152  0.000000

# %%
diff_2021 = diff_2021[['Year','Country name','Ladder score','Healthy life expectancy','Explained by: Perceptions of corruption','Generosity','Logged GDP per capita','Explained by: Freedom to make life choices']]
diff_2021.rename(columns={'Ladder score':'Happiness'},inplace=True)
diff_2021.rename(columns={'Healthy life expectancy':'Health'},inplace=True)
diff_2021.rename(columns={'Explained by: Perceptions of corruption':'Trust'},inplace=True)
diff_2021.rename(columns={'Logged GDP per capita':'Economy'},inplace=True)
diff_2021.rename(columns={'Explained by: Freedom to make life choices':'Freedom'},inplace=True)
diff_2021.rename(columns={'Country name':'Country'},inplace=True)
diff_2021
# Out:
#      Year      Country  Happiness  Health  Trust  Generosity  Economy  Freedom
# 2    2021  Switzerland      7.571  74.400  0.413       0.025   11.117    0.653
# 148  2021  Afghanistan      2.523  52.493  0.010      -0.102    7.695    0.000

# %%
diff_2022 = diff_2022[['Year','Country','Happiness score','Explained by: Healthy life expectancy','Explained by: Perceptions of corruption','Explained by: Generosity','Explained by: GDP per capita','Explained by: Freedom to make life choices']]
diff_2022.rename(columns={'Happiness score':'Happiness'},inplace=True)
diff_2022.rename(columns={'Explained by: Healthy life expectancy':'Health'},inplace=True)
diff_2022.rename(columns={'Explained by: Perceptions of corruption':'Trust'},inplace=True)
diff_2022.rename(columns={'Explained by: GDP per capita':'Economy'},inplace=True)
diff_2022.rename(columns={'Explained by: Freedom to make life choices':'Freedom'},inplace=True)
diff_2022.rename(columns={'Country name':'Country'},inplace=True)
diff_2022.rename(columns={'Explained by: Generosity':'Generosity'},inplace=True)
diff_2022
# Out:
#      Year      Country Happiness Health  Trust Generosity Economy Freedom
# 3    2022  Switzerland     7,512  0,822  0,461      0,147   2,026   0,677
# 145  2022  Afghanistan     2,404  0,289  0,005      0,089   0,758   0,000

# %%
pd.to_numeric(diff_2022['Happiness'].str.replace(',',''))
pd.to_numeric(diff_2022['Health'].str.replace(',',''))
pd.to_numeric(diff_2022['Trust'].str.replace(',',''))
pd.to_numeric(diff_2022['Generosity'].str.replace(',',''))
pd.to_numeric(diff_2022['Economy'].str.replace(',',''))
pd.to_numeric(diff_2022['Freedom'].str.replace(',',''))
diff_2022
# Out:
#      Year      Country Happiness Health  Trust Generosity Economy Freedom
# 3    2022  Switzerland     7,512  0,822  0,461      0,147   2,026   0,677
# 145  2022  Afghanistan     2,404  0,289  0,005      0,089   0,758   0,000

# %%
diff = pd.concat([diff_2015,diff_2016,diff_2017,diff_2018,diff_2019,diff_2020,diff_2021,diff_2022])
diff
# Out:
#      Year      Country Happiness     Health     Trust Generosity    Economy  \
# 0    2015  Switzerland     7.587    0.94143   0.41978    0.29678    1.39651
# 152  2015  Afghanistan     3.575    0.30335   0.09719     0.3651    0.31982
# 1    2016  Switzerland     7.509    0.86303   0.41203    0.28083    1.52733
# 153  2016  Afghanistan      3.36    0.17344   0.07112    0.31268    0.38227
# 3    2017  Switzerland     7.494   0.858131  0.367007   0.290549    1.56498
# 140  2017  Afghanistan     3.794   0.180747  0.061158   0.311871   0.401477
# 4    2018  Switzerland     7.487      0.927     0.357      0.256       1.42
# 144  2018  Afghanistan     3.632      0.255     0.036      0.191      0.332
# 5    2019  Switzerland      7.48      1.052     0.343      0.263      1.452
# 153  2019  Afghanistan     3.203      0.361     0.025      0.158       0.35
# 2    2020  Switzerland    7.5599  74.102448  0.407946   0.105911  10.979933
# ...

# %%
diff.to_csv("C:/Users/kzking/Desktop/archive/new.csv")

# %%
diff = pd.read_csv("C:/Users/kzking/Desktop/archive/new.csv")
diff
# Out:
#     Unnamed: 0  Year      Country  Happiness     Health     Trust  Generosity  \
# 0            0  2015  Switzerland     7.5870   0.941430  0.419780    0.296780
# 1          152  2015  Afghanistan     3.5750   0.303350  0.097190    0.365100
# 2            1  2016  Switzerland     7.5090   0.863030  0.412030    0.280830
# 3          153  2016  Afghanistan     3.3600   0.173440  0.071120    0.312680
# 4            3  2017  Switzerland     7.4940   0.858131  0.367007    0.290549
# 5          140  2017  Afghanistan     3.7940   0.180747  0.061158    0.311871
# 6            4  2018  Switzerland     7.4870   0.927000  0.357000    0.256000
# 7          144  2018  Afghanistan     3.6320   0.255000  0.036000    0.191000
# 8            5  2019  Switzerland     7.4800   1.052000  0.343000    0.263000
# 9          153  2019  Afghanistan     3.2030   0.361000  0.025000    0.158000
# 10           2  2020  Switzerland     7.5599  74.102448  0.407946    0.105911
# ...

# %%
year = [2015,2016,2017,2018,2019,2020,2021,2022]
happiness  = [3.575,3.36,3.79399991,3.632,3.203,2.566900015,2.523,26]

 
 



 
x = [2015,2016,2017,2018,2019,2020,2021,2022]
y_train = [0.23414,0.1643,0.10617952,0.085,0,0,0,0]
y_test  = [0.66557,0.58557,0.620070577,0.66,0.572,0.62895447,0.653,0.677]
#plt.plot(x, y, 'ro-')
#plt.plot(x, y1, 'bo-')
#pl.xlim(-1, 11)  # 限定横轴的范围
#pl.ylim(-1, 110)  # 限定纵轴的范围
 
 
plt.plot(x, y_train, marker='o', mec='r', mfc='w',label='Afghanistan')
plt.plot(x, y_test, marker='*', ms=10,label='Switzerland')
plt.legend()  # 让图例生效

 
plt.margins(0)
plt.subplots_adjust(bottom=0.10)
plt.xlabel('the length') #X轴标签
plt.ylabel("f1") #Y轴标签
pyplot.yticks([0.750,0.800,0.850])
plt.title("Happiness") #标题
plt.savefig('D:\\f1.jpg',dpi = 900)
